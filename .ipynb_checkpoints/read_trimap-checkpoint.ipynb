# %%
#  M. Amintoosi
#  Read trimap image
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import glob
import argparse

# import utils

# import torch
import torchvision.transforms.functional as TF

in_size = 256

datadir = r'./images/custom'
val_dirs = glob.glob(os.path.join(datadir, 'dog*.jpg'))
datadir_flowers = r'./images/custom'
val_dirs_flowers = glob.glob(os.path.join(datadir_flowers, 'flower*.jpg'))

idx = 0
img1 = cv2.imread(val_dirs[idx], cv2.IMREAD_COLOR)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread(val_dirs_flowers[idx], cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)


# we recommend to use TF.resize since it was also used during trainig
# You may also try cv2.resize, but it will produce slightly different results
gt1 = TF.resize(TF.to_pil_image(img1), [in_size, in_size])
gt1 = 0.5*TF.to_tensor(gt1).unsqueeze(0)
gt2 = TF.resize(TF.to_pil_image(img2), [in_size, in_size])
gt2 = 0.5*TF.to_tensor(gt2).unsqueeze(0)
img_mix = gt1 + gt2

# cv2.imshow(img_mix)

# %%
print(img_mix.shape)
window_name = 'mix'
# image = img_mix[0].transpose((1, 2, 0))
image = np.transpose(np.asarray(img_mix[0].squeeze()),(1,2,0))
print(image.shape)
plt.imshow(image)
# cv2.imshow(window_name,image.detach().cpu().numpy())
# cv2.waitKey(0) 
# cv2.destroyAllWindows()
# Out:
# torch.Size([1, 3, 256, 256])
# (256, 256, 3)

# %%
path = r'C:/temp/git/Deep-adversarial-decomposition/images/custom/dog.986_flower.sun_trimap.png'
  
# Reading an image in default mode
image = cv2.imread(path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
print(image.min(), image.max())
# Out:
# 0 255

# %%
mask1 = image == 255
mask1 = mask1.astype(np.uint8)
mask1 *= 255
print(type(image[0,0,0]),type(mask1[0,0,0]),mask1.shape)
plt.imshow(mask1)
# Out:
# <class 'numpy.uint8'> <class 'numpy.uint8'> (256, 256, 3)
